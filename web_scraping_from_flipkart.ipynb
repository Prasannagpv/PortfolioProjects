# %%
from bs4 import BeautifulSoup
import requests
import time
import datetime

import smtplib

# %%
URL='https://www.flipkart.com/motorola-edge-40-coronet-blue-256-gb/p/itm32e082b2d4213?pid=MOBGKHNBYGH5KHJ9&param=11111&otracker=clp_bannerads_1_17.bannerAdCard.BANNERADS_A_mobile-phones-store_CKJJDZYB503K'
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36",
        "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8", 
        "Accept-Encoding": "gzip, deflate, br", 
        "Accept-Language": "en-US,en",
        "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

page = requests.get(URL, headers=headers)

soup1 = BeautifulSoup(page.content, "html.parser")


#soup2 = BeautifulSoup(soup1.prettify(), "html.parser")

title = soup1.find("span",attrs={"class":"B_NuCI"}).text

print(title)
#title
# Out:
# MOTOROLA Edge 40 (Lunar Blue, 256 GB)  (8 GB RAM)

# %%
today=datetime.date.today()

print(today)
# Out:
# 2023-07-12

# %%
price = soup1.find("div", attrs={"class":"_30jeq3 _16Jk6d"}).text

price=price.strip()[1:]
print(price)

type(price)
# Out:
# 29,999
# str

# %%
import csv

header=['title','price','today']

data=[title,price,today]

#with open("flipkart_web_scraper_dataset.csv",'w',newline='',encoding='UTF8')as f:
    
    #writer=csv.writer(f)
    #writer.writerow(header)
    #writer.writerow(data)

# %%
import pandas as pd

df=pd.read_csv(r"C:\Users\geeth\flipkart_web_scraper_dataset.csv")
df
# Out:
#                                                 title   price       today
# 0   MOTOROLA Edge 40 (Lunar Blue, 256 GB)  (8 GB RAM)  29,999  2023-07-12
# 1   MOTOROLA Edge 40 (Lunar Blue, 256 GB)  (8 GB RAM)  29,999  2023-07-12
# 2   MOTOROLA Edge 40 (Lunar Blue, 256 GB)  (8 GB RAM)  29,999  2023-07-12
# 3   MOTOROLA Edge 40 (Lunar Blue, 256 GB)  (8 GB RAM)  29,999  2023-07-12
# 4   MOTOROLA Edge 40 (Lunar Blue, 256 GB)  (8 GB RAM)  29,999  2023-07-12
# 5   MOTOROLA Edge 40 (Lunar Blue, 256 GB)  (8 GB RAM)  29,999  2023-07-12
# 6   MOTOROLA Edge 40 (Lunar Blue, 256 GB)  (8 GB RAM)  29,999  2023-07-12
# 7   MOTOROLA Edge 40 (Lunar Blue, 256 GB)  (8 GB RAM)  29,999  2023-07-12
# 8   MOTOROLA Edge 40 (Lunar Blue, 256 GB)  (8 GB RAM)  29,999  2023-07-12
# 9   MOTOROLA Edge 40 (Lunar Blue, 256 GB)  (8 GB RAM)  29,999  2023-07-12
# 10  MOTOROLA Edge 40 (Lunar Blue, 256 GB)  (8 GB RAM)  29,999  2023-07-12
# 11  MOTOROLA Edge 40 (Lunar Blue, 256 GB)  (8 GB RAM)  29,999  2023-07-12
# 12  MOTOROLA Edge 40 (Lunar Blue, 256 GB)  (8 GB RAM)  29,999  2023-07-12
# 13  MOTOROLA Edge 40 (Lunar Blue, 256 GB)  (8 GB RAM)  29,999  2023-07-12
# 14  MOTOROLA Edge 40 (Lunar Blue, 256 GB)  (8 GB RAM)  29,999  2023-07-12
# 15  MOTOROLA Edge 40 (Lunar Blue, 256 GB)  (8 GB RAM)  29,999  2023-07-12
# 16  MOTOROLA Edge 40 (Lunar Blue, 256 GB)  (8 GB RAM)  29,999  2023-07-12
# 17  MOTOROLA Edge 40 (Lunar Blue, 256 GB)  (8 GB RAM)  29,999  2023-07-12
# 18  MOTOROLA Edge 40 (Lunar Blue, 256 GB)  (8 GB RAM)  29,999  2023-07-12
# 19  MOTOROLA Edge 40 (Lunar Blue, 256 GB)  (8 GB RAM)  29,999  2023-07-12
# 20  MOTOROLA Edge 40 (Lunar Blue, 256 GB)  (8 GB RAM)  29,999  2023-07-12
# 21  MOTOROLA Edge 40 (Lunar Blue, 256 GB)  (8 GB RAM)  29,999  2023-07-12
# 22  MOTOROLA Edge 40 (Lunar Blue, 256 GB)  (8 GB RAM)  29,999  2023-07-12
# 23  MOTOROLA Edge 40 (Lunar Blue, 256 GB)  (8 GB RAM)  29,999  2023-07-12
# 24  MOTOROLA Edge 40 (Lunar Blue, 256 GB)  (8 GB RAM)  29,999  2023-07-12
# 25  MOTOROLA Edge 40 (Lunar Blue, 256 GB)  (8 GB RAM)  29,999  2023-07-12
# 26  MOTOROLA Edge 40 (Lunar Blue, 256 GB)  (8 GB RAM)  29,999  2023-07-12
# 27  MOTOROLA Edge 40 (Lunar Blue, 256 GB)  (8 GB RAM)  29,999  2023-07-12
# 28  MOTOROLA Edge 40 (Lunar Blue, 256 GB)  (8 GB RAM)  29,999  2023-07-12
# 29  MOTOROLA Edge 40 (Lunar Blue, 256 GB)  (8 GB RAM)  29,999  2023-07-12
# 30  MOTOROLA Edge 40 (Lunar Blue, 256 GB)  (8 GB RAM)  29,999  2023-07-12
# 31  MOTOROLA Edge 40 (Lunar Blue, 256 GB)  (8 GB RAM)  29,999  2023-07-12
# 32  MOTOROLA Edge 40 (Lunar Blue, 256 GB)  (8 GB RAM)  29,999  2023-07-12
# 33  MOTOROLA Edge 40 (Lunar Blue, 256 GB)  (8 GB RAM)  29,999  2023-07-12
# 34  MOTOROLA Edge 40 (Lunar Blue, 256 GB)  (8 GB RAM)  29,999  2023-07-12
# 35  MOTOROLA Edge 40 (Lunar Blue, 256 GB)  (8 GB RAM)  29,999  2023-07-12

# %%
with open("flipkart_web_scraper_dataset.csv",'a+',newline='',encoding='UTF8')as f:
    
    writer=csv.writer(f)
    
    writer.writerow(data)

# %%
import smtplib


def send_mail():
    
    server= smtplib.SMTP('smtp.gmail.com',587)
    
    server.starttls()
    
    server.login('prasannavenkatesh2105@gmail.com','pmehlyszfjgqwhlu')
     
    subject=" CHECK OUT THIS SUPER DEAL ORDER NOW!!!!  "
    
    body= "The price have droped for the phone , order now ASAP! LIMITED DEAL !!!!!!!!!"
    
    msg= f"subject:{subject}\n\n{body}"
    
    server.sendmail('prasannavenkatesh2105@gmail.com','prasannavenkateshg21@gmail.com',msg)
    
    print("mail sent")

# %%
def check_price():
    
    URL='https://www.flipkart.com/motorola-edge-40-coronet-blue-256-gb/p/itm32e082b2d4213?pid=MOBGKHNBYGH5KHJ9&param=11111&otracker=clp_bannerads_1_17.bannerAdCard.BANNERADS_A_mobile-phones-store_CKJJDZYB503K'
    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36",
        "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8", 
        "Accept-Encoding": "gzip, deflate, br", 
        "Accept-Language": "en-US,en",
        "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

    page = requests.get(URL, headers=headers)

    soup1 = BeautifulSoup(page.content, "html.parser")


    #soup2 = BeautifulSoup(soup1.prettify(), "html.parser")

    title = soup1.find("span",attrs={"class":"B_NuCI"}).text
    
    price = soup1.find("div", attrs={"class":"_30jeq3 _16Jk6d"}).text
    
    price=price.strip()[1:]
    
    today=datetime.date.today()
    
    
    import csv

    header=['title','price','today']

    data=[title,price,today]
    
    with open("flipkart_web_scraper_dataset.csv",'a+',newline='',encoding='UTF8')as f:
    
        writer=csv.writer(f)

        writer.writerow(data)

# %%
while(True):
    check_price()
    time.sleep(5)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[121], line 3
#       1 while(True):
#       2     check_price()
# ----> 3     time.sleep(5)
#
# KeyboardInterrupt:

# %%
import pandas as pd

df=pd.read_csv(r"C:\Users\geeth\flipkart_web_scraper_dataset.csv")
df
if price=="29,999":
               send_mail()
# Out:
# mail sent
